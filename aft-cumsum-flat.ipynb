# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import pytorch_lightning as pl
import datasets
import numpy as np

pl.seed_everything(89026614)

text = datasets.load_dataset('tiny_shakespeare')["train"][0]["text"]
#text = open('../../Downloads/simplebooks/simplebooks-2-raw/train.txt', 'r').read()
# Out:
# Global seed set to 89026614
# Found cached dataset tiny_shakespeare (/Users/cztomsik/.cache/huggingface/datasets/tiny_shakespeare/default/1.0.0/b5b13969f09fe8707337f6cb296314fbe06960bd9a868dca39e713e163d27b5e)
#
# 100%|██████████| 3/3 [00:00<00:00, 809.45it/s]

# %%
device = "cpu"
block_size = 100

class MyDataset(data.Dataset):
    def __init__(self, text):
        super().__init__()
        vocab = sorted(set(text))
        self.vocab = vocab
        self.stoi = { ch: i for i, ch in enumerate(vocab) }
        self.itos = { i: ch for i, ch in enumerate(vocab) }
        self.data = torch.tensor([self.stoi[ch] for ch in text], dtype=torch.long).to(device)

    def __len__(self):
        return self.data.size(0) - block_size - 1

    def __getitem__(self, i):
        end = i + block_size
        return self.data[i:end], self.data[i + 1:end + 1]

dataset = MyDataset(text)
train = data.Subset(dataset, range(0, len(dataset) - 500))
test = data.Subset(dataset, range(len(dataset) - 500, len(dataset)))

# %%
# inspired by https://github.com/karpathy/minGPT/blob/master/mingpt/model.py
class MinGPT(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_layers, dropout):
        super().__init__()
        self.transformer = nn.Sequential(
            nn.Embedding(vocab_size, embed_dim),
            nn.Dropout(dropout),
            nn.Sequential(*[DecoderLayer(embed_dim, dropout) for _ in range(num_layers)]),
            nn.LayerNorm(embed_dim),
        )
        self.lm_head = nn.Linear(embed_dim, vocab_size, bias=False)
    
    def forward(self, x):
        return self.lm_head(self.transformer(x))

    @torch.no_grad()
    def generate(self, input_ids, max_new_tokens, top_k=10):
        for _ in range(max_new_tokens):
            out = self(input_ids[:, -block_size:])
            logits = out[:, -1, :]
            v, _ = torch.topk(logits, top_k)
            logits[logits < v[:, [-1]]] = -float("Inf")
            step_res = torch.multinomial(F.softmax(logits, dim=-1), num_samples=1)
            # auto-regression
            input_ids = torch.cat((input_ids, step_res), dim=1)

        return input_ids

class DecoderLayer(nn.Module):
    def __init__(self, embed_dim, dropout):
        super().__init__()
        self.ln1 = nn.LayerNorm(embed_dim)
        self.attn = AFTFullLinearCumsum(embed_dim, dropout)
        self.ln2 = nn.LayerNorm(embed_dim)
        self.mlp = nn.Sequential(
            nn.Linear(embed_dim, 4 * embed_dim),
            nn.GELU(approximate="tanh"),
            nn.Linear(4 * embed_dim, embed_dim),
            nn.Dropout(dropout)
        )
        self.register_buffer("mask", torch.tril(torch.ones(block_size, block_size)).to(device))

    def forward(self, x):
        B, T, _ = x.shape
        x = self.ln1(x)
        x = x + self.attn(x, self.mask)
        x = x + self.mlp(self.ln2(x))
        return x

# https://arxiv.org/pdf/2105.14103.pdf
# but w is flat vector, it's not expenentiated and we divide by
# cumulative sum of exp(k) instead of exp(w) @ exp(k)
class AFTFullLinearCumsum(nn.Module):
    def __init__(self, embed_dim, dropout):
        super().__init__()
        self.qkv = nn.Linear(embed_dim, embed_dim * 3)
        self.w_decay = nn.Parameter(torch.ones(block_size), requires_grad=True)
        self.proj = nn.Linear(embed_dim, embed_dim)
        self.drop = nn.Dropout(dropout)
    
    def forward(self, x, mask):
        B, T, C = x.shape
        q, k, v = self.qkv(x).chunk(3, dim=-1)

        w = torch.einsum("ij,j->ij", mask[:T, :T], self.w_decay[:T])
        exp_k = k.exp()

        weighted_avg = torch.einsum("ik,bkj->bij", w, exp_k * v) / torch.cumsum(exp_k, dim=1)
        Yt = F.sigmoid(q) * weighted_avg

        return self.drop(self.proj(Yt))


class Model(pl.LightningModule):
    def __init__(self, vocab_size, lr=0.004):
        super().__init__()
        self.lr = lr
        self.model = MinGPT(vocab_size, embed_dim=192, num_layers=3, dropout=0.1)
    
    def forward(self, x, y=None):
        logits = self.model(x)
        return logits if y is None else F.cross_entropy(logits.view(-1, logits.size(-1)), y.view(-1), ignore_index=-1)

    def train_dataloader(self):
        return data.DataLoader(train, batch_size=100, num_workers=0, sampler=data.RandomSampler(train, False, 5_000))

    def training_step(self, batch, batch_idx):
        return self(*batch)

    def val_dataloader(self):
        return data.DataLoader(test, batch_size=16, num_workers=0)
    
    def validation_step(self, batch, batch_idx):
        loss = self(*batch)
        self.log("test_loss", loss, prog_bar=True, on_step=False, on_epoch=True)
        return loss

    def validation_epoch_end(self, outs):
        with torch.no_grad():
            x = torch.tensor([dataset.stoi[s] for s in "And now "], dtype=torch.long)[None,...].to(device)
            y = self.model.generate(x, 64)[0]
            print("".join([dataset.itos[int(i)] for i in y]))

    def configure_optimizers(self):
        optim = torch.optim.AdamW(self.parameters(), lr=self.lr)
        sched = torch.optim.lr_scheduler.ExponentialLR(optim, gamma=0.999, last_epoch=-1)
        return [optim], [sched]

model = Model(len(dataset.vocab))
trainer = pl.Trainer(gradient_clip_val=1.0, max_epochs=25, enable_progress_bar=True, accelerator="gpu" if device == "cuda" else "cpu")
trainer.fit(model)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name  | Type   | Params
# ---------------------------------
# 0 | model | MinGPT | 1.4 M
# ---------------------------------
# 1.4 M     Trainable params
# 0         Non-trainable params
# 1.4 M     Total params
# 5.441     Total estimated model params size (MB)
# Sanity Checking DataLoader 0: 100%|██████████| 2/2 [00:00<00:00, 34.07it/s]And now -k
# B&Y,upRo&tjRQzvYFk
# R.
# AEVpAz'KCi3vLQqKCrVUDya.VGgAl yIhduObgH
# Epoch 0: 100%|██████████| 82/82 [00:22<00:00,  3.59it/s, loss=2.46, v_num=96]And now a m town han toucent tourt s moueeted at mur aith wir imerot t a
# Epoch 1: 100%|██████████| 82/82 [00:23<00:00,  3.44it/s, loss=2.31, v_num=96, test_loss=2.400]And now sotild.
# SALINT:
# Whe t timyou we myou.
#
# MENEO:
# BO thet bow my, wi
# Epoch 2: 100%|██████████| 82/82 [00:23<00:00,  3.43it/s, loss=2.23, v_num=96, test_loss=2.250]And now ay storther,
# Trero heitelll, shou that mo therusingh s dofedelse
# Epoch 3: 100%|██████████| 82/82 [00:23<00:00,  3.45it/s, loss=2.06, v_num=96, test_loss=2.220]And now that stow.
# Wen thist wern spacas, you, ands mor the friol
# Tour h
# Epoch 4: 100%|██████████| 82/82 [00:23<00:00,  3.48it/s, loss=1.94, v_num=96, test_loss=2.040]And now belaty. Hery hat? my the's mant
# sing singnt, I was hat would be
# Epoch 5: 100%|██████████| 82/82 [00:23<00:00,  3.49it/s, loss=1.86, v_num=96, test_loss=1.960]And now them wore of deyes spoir
# Inty. Lord this he musind hee, then hea
# Epoch 6: 100%|██████████| 82/82 [00:23<00:00,  3.51it/s, loss=1.78, v_num=96, test_loss=1.850]And now my horeld
# Be more wordshond the put thereful'd of his both
# This
# Epoch 7: 100%|██████████| 82/82 [00:23<00:00,  3.53it/s, loss=1.73, v_num=96, test_loss=1.770]And now thee beid which shoulds woman ofth!
# Sporthant in sto takes these
# Epoch 8: 100%|██████████| 82/82 [00:23<00:00,  3.54it/s, loss=1.7, v_num=96, test_loss=1.710] And now all, who swell shall wel hort
# As sucon to his hearst son that so
# Epoch 9: 100%|██████████| 82/82 [00:23<00:00,  3.53it/s, loss=1.66, v_num=96, test_loss=1.710]And now her: I lovy sill not,
# Turrn by say she marrial, sir, you; my sou
# Epoch 10: 100%|██████████| 82/82 [00:23<00:00,  3.53it/s, loss=1.64, v_num=96, test_loss=1.650]And now your soul
# And think my find
# And inswer a morer obles me a propes
# Epoch 11: 100%|██████████| 82/82 [00:23<00:00,  3.54it/s, loss=1.61, v_num=96, test_loss=1.590]And now hath lay out his
# to say the dosterited, by to too were comond,
# A
# Epoch 12: 100%|██████████| 82/82 [00:23<00:00,  3.55it/s, loss=1.59, v_num=96, test_loss=1.610]And now with with the cannd slike?
#
# First Gentleman:
# He can hathes bones
# Epoch 13: 100%|██████████| 82/82 [00:23<00:00,  3.56it/s, loss=1.57, v_num=96, test_loss=1.560]And now thy friar the feather alow with the
# at honest, from to of myst;
# Epoch 14: 100%|██████████| 82/82 [00:22<00:00,  3.58it/s, loss=1.55, v_num=96, test_loss=1.550]And now with to be men, by seek to full wears, thought;
# But mees as your
# Epoch 15: 100%|██████████| 82/82 [00:23<00:00,  3.56it/s, loss=1.55, v_num=96, test_loss=1.550]And now hours; which wants to be thy shames;
# Thing the till him thou hat
# Epoch 16: 100%|██████████| 82/82 [00:23<00:00,  3.56it/s, loss=1.54, v_num=96, test_loss=1.550]And now am shall be privide
# As band all heaven our fait a leads,
# For in
# Epoch 17: 100%|██████████| 82/82 [00:23<00:00,  3.55it/s, loss=1.51, v_num=96, test_loss=1.500]And now the woman are!
#
# AUFIDIUS:
# No?
# This in.
#
# CAMILLLO:
# And hapiend so
# Epoch 18: 100%|██████████| 82/82 [00:23<00:00,  3.53it/s, loss=1.52, v_num=96, test_loss=1.520]And now me my calments to call speak to myself.
#
# GLOUCESTER:
# Why, let yo
# Epoch 19: 100%|██████████| 82/82 [00:22<00:00,  3.58it/s, loss=1.5, v_num=96, test_loss=1.480] And now more wondeds of my
# That tritor thy cannot peach with in blood
# Wh
# Epoch 20: 100%|██████████| 82/82 [00:22<00:00,  3.59it/s, loss=1.49, v_num=96, test_loss=1.460]And now by save in your sea. Your hold case an these
# In shall the purse
# Epoch 21: 100%|██████████| 82/82 [00:22<00:00,  3.59it/s, loss=1.5, v_num=96, test_loss=1.490] And now her new-say the can the honour's
# Which is spuit have here.
#
# AULI
# Epoch 22: 100%|██████████| 82/82 [00:23<00:00,  3.56it/s, loss=1.48, v_num=96, test_loss=1.490]And now almen of weated in their,
# Which have thou hath seems many of tri
# Epoch 23: 100%|██████████| 82/82 [00:23<00:00,  3.53it/s, loss=1.48, v_num=96, test_loss=1.450]And now no promiseds.
#
# KING EDWARD IV:
# Ah, sir? and thousand welcome my
# Epoch 24: 100%|██████████| 82/82 [00:22<00:00,  3.57it/s, loss=1.46, v_num=96, test_loss=1.450]And now we stay for merroved, and die.
#
# LADY ANNNE:
# His deligh father th
# Epoch 24: 100%|██████████| 82/82 [00:23<00:00,  3.54it/s, loss=1.46, v_num=96, test_loss=1.480]
# `Trainer.fit` stopped: `max_epochs=25` reached.
# Epoch 24: 100%|██████████| 82/82 [00:23<00:00,  3.54it/s, loss=1.46, v_num=96, test_loss=1.480]

# %%
y = model.to(device).model.generate(torch.tensor([dataset.stoi[s] for s in "O God, O God!"]).unsqueeze(0).to(device), 650)
print("".join([dataset.itos[int(i)] for i in y[0]]))
# Out:
# O God, O God! and me with the best he
# And wit beg weebon spointence.
#
# BENVOLIOLIO:
# Stay the these feen the dineath peace,
# And preatuable of my blood.
#
# LUCIO:
# Banch you hands
# Why my deelest of your seccolud or him;
# For you have dead, my but contrices to heaven
# In your shreast thee done of a din surbs.
#
# KING MAR III:
# Say I takner of.
#
# DUKE OF YORK:
# Norfolk, sea the guiltly for this shapes of my
# that's stut an to dramb'd own by the heinest.
# Farer what's nughter.
#
# BENVOLION:
# If this he maners then father slufe.
#
# PRINCE EDWARD:
# Who say too; I am igning; broth, I priy, sin,
# The writ thou that we are with day to depace,
# Those for signify and to your hands her
# Wh
